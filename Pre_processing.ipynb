# %%
import pandas as pd
data = pd.read_csv("data_kpu.csv", sep=";")
data.head(10)
# Out:
#                        created_at               id_str  \
# 0  Wed Dec 27 23:25:37 +0000 2023  1740151983099859248
# 1  Wed Dec 27 09:30:53 +0000 2023  1739941915867718045
# 2  Tue Dec 26 17:32:37 +0000 2023  1739700757065355429
# 3  Fri Dec 22 15:03:22 +0000 2023  1738213646843642137
# 4  Fri Dec 22 12:58:03 +0000 2023  1738182110119342367
# 5  Fri Dec 22 10:51:32 +0000 2023  1738150272214741111
# 6  Fri Dec 15 12:53:45 +0000 2023  1735644313642754158
# 7  Fri Dec 15 06:03:07 +0000 2023  1735540972497563849
# 8  Tue Dec 12 08:04:21 +0000 2023  1734484320532725908
# 9  Mon Dec 11 11:31:48 +0000 2023  1734174136229072964
#
#                                            full_text  quote_count  \
# 0  @tvOneNews Inikah dampak data pemilih yg bocor...            0
# 1  Bisa gak sih ada Mosi Tidak Percaya sama KPU? ...            1
# 2  @msaid_didu @Mazing93 Gibran dapet giliran PER...            0
# 3  Y mau bagaimana lagi, Indonesia butuh seorang ...            0
# 4  204 Juta Data Pemilih Bocor Dibobol Hacker, KP...            0
# 5  KPU sebagai penyelenggara pemilu harus sangat ...            0
# 6  Memang @KPU_ID punya 'TOOLS' apa utk mendalami...            0
# 7  @Mbok_Ewett bs jadi hoax doang 🙈🤭  buktinya vi...            0
# 8  Sebanyak 204 juta data Daftar Pemilih Tetap (D...            0
# 9  @Metro_TV Data pemilih yang terus bocor menjad...            0
#
#    reply_count  retweet_count  favorite_count lang          user_id_str  \
# 0            0              0               0   in  1185713156116533254
# 1            3              4              21   in            267795457
# 2            1              0               4   in            267795457
# 3            0              3               4   in           1978790995
# 4            0              0               0   in             30622684
# 5            0              0               0   in   874558344593195008
# 6            0              0               0   in             95284447
# 7            0              0               0   in            374002526
# 8         1000              1               0   in            135815019
# 9            0              0               0   in  1725678046815092736
#
#    conversation_id_str         username  \
# 0  1739977656098250894  JohnPhi42491333
# 1  1739941915867718045       AdamVelcro
# 2  1739633482983440719       AdamVelcro
# 3  1738213646843642137      LaingenLisa
# 4  1738181730052510102         kenarrox
# 5  1738150272214741111      validnewsid
# 6  1735644313642754158       wong_w4r4s
# 7  1735509682033463613     iccasarifien
# 8  1734484320532725908        detikinet
# 9  1734110230638924148         Deifriel
#
#                                            tweet_url
# 0  https://twitter.com/JohnPhi42491333/status/174...
# 1  https://twitter.com/AdamVelcro/status/17399419...
# 2  https://twitter.com/AdamVelcro/status/17397007...
# 3  https://twitter.com/LaingenLisa/status/1738213...
# 4  https://twitter.com/kenarrox/status/1738182110...
# 5  https://twitter.com/validnewsid/status/1738150...
# 6  https://twitter.com/wong_w4r4s/status/17356443...
# 7  https://twitter.com/iccasarifien/status/173554...
# 8  https://twitter.com/detikinet/status/173448432...
# 9  https://twitter.com/Deifriel/status/1734174136...

# %%
print(data['full_text'][1])
# Out:
# Bisa gak sih ada Mosi Tidak Percaya sama KPU? Soalnya org2 nya piliham Mukidi semua.. ingat data pemilih bocor di server KPU trus ada yg jual? 🤦🏻‍♂️

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 199 entries, 0 to 198
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   created_at           199 non-null    object
#  1   id_str               199 non-null    int64
#  2   full_text            199 non-null    object
#  3   quote_count          199 non-null    int64
#  4   reply_count          199 non-null    int64
#  5   retweet_count        199 non-null    int64
#  6   favorite_count       199 non-null    int64
#  7   lang                 199 non-null    object
#  8   user_id_str          199 non-null    int64
#  9   conversation_id_str  199 non-null    int64
#  10  username             199 non-null    object
#  11  tweet_url            199 non-null    object
# dtypes: int64(7), object(5)
# memory usage: 18.8+ KB

# %%
#statistik dataset menghasilkan ringkasan statistik dari dataset, seperti mean, standar deviasi, nilai minimum, kuartil, dan nilai maksimum.
summary = data.describe()
summary.head()
# Out:
#              id_str  quote_count  reply_count  retweet_count  favorite_count  \
# count  1.990000e+02   199.000000   199.000000     199.000000      199.000000
# mean   1.731095e+18     0.527638    16.592965       4.587940       10.643216
# std    2.012564e+15     1.989363   123.176395      17.710667       45.408453
# min    1.729658e+18     0.000000     0.000000       0.000000        0.000000
# 25%    1.729817e+18     0.000000     0.000000       0.000000        0.000000
#
#         user_id_str  conversation_id_str
# count  1.990000e+02         1.990000e+02
# mean   6.999114e+17         1.731082e+18
# std    7.419637e+17         2.001411e+15
# min    1.712898e+07         1.729492e+18
# 25%    7.185517e+07         1.729817e+18

# %%
#vis original data wordcloud & frekuensi data
import pandas as pd
import numpy as np
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import matplotlib.pyplot as plt
df = ' '.join(data['full_text'].tolist())

stopwords = set(STOPWORDS)
stopwords.update(['https', 'co', 'RT', '...', 'amp'])
wc = WordCloud(stopwords=stopwords, background_color="black", max_words=100, height=400, width= 800)
wc.generate(df)

plt.figure(figsize=(10, 5))
plt.imshow(wc, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
#kata yang sering muncul
import matplotlib.pyplot as plt
from collections import Counter

text=" ".join(data["full_text"])

tokens = text.split()
word_counts = Counter(tokens)

top_words = word_counts.most_common(10)
word, count = zip(*top_words)

colors = plt.cm.Paired(range(len(word)))

plt.figure(figsize=(10, 6))
bars = plt.bar(word, count, color=colors)
plt.xlabel("Kata")
plt.ylabel("Frekuensi")
plt.title("Kata-kata yang sering muncul")
plt.xticks(rotation=45)

for bar, num in zip(bars, count):
  plt.text(bar.get_x() + bar.get_width() / 2 - 0.1, num+ 1, str(num), fontsize=12, color='black', ha='center')

plt.show()

# %%
#pre-processing data
df = pd.DataFrame(data[['full_text']])
df.head()
# Out:
#                                            full_text
# 0  @tvOneNews Inikah dampak data pemilih yg bocor...
# 1  Bisa gak sih ada Mosi Tidak Percaya sama KPU? ...
# 2  @msaid_didu @Mazing93 Gibran dapet giliran PER...
# 3  Y mau bagaimana lagi, Indonesia butuh seorang ...
# 4  204 Juta Data Pemilih Bocor Dibobol Hacker, KP...

# %%
import re
import string
import nltk

def remove_URL(tweet):
    url = re.compile(r'https?://\S+|www\.\S+')
    return url.sub(r'', tweet)

def remove_html(tweet):
    html = re.compile(r'<.*?>')
    return html.sub(r'', tweet)

def remove_emoji(tweet):
    emoji_pattern = re.compile("["
        u"\U0001F600-\U0001F64F"
        u"\U0001F300-\U0001F5FF"
        u"\U0001F680-\U0001F6FF"
        u"\U0001F1E0-\U0001F1FF"
        "]+", flags=re.UNICODE)
    return emoji_pattern.sub(r'', tweet)

def remove_angka(tweet):
    tweet = re.sub('[0-9]+', '', tweet)
    tweet = re.sub(r'\$\w*', '', tweet)
    tweet = re.sub(r'^RT[\s]+', '', tweet)
    tweet = re.sub(r'#', '', tweet)
    return tweet

def remove_punct(tweets):
    translator = str.maketrans('', '', string.punctuation)
    return tweets.translate(translator)

df['cleansing'] = df['full_text'].apply(lambda x: remove_URL(x))
df['cleansing'] = df['cleansing'].apply(lambda x: remove_html(x))
df['cleansing'] = df['cleansing'].apply(lambda x: remove_emoji(x))
df['cleansing'] = df['cleansing'].apply(lambda x: remove_punct(x))
df['cleansing'] = df['cleansing'].apply(lambda x: remove_angka(x))

df.head()
# Out:
#                                            full_text  \
# 0  @tvOneNews Inikah dampak data pemilih yg bocor...
# 1  Bisa gak sih ada Mosi Tidak Percaya sama KPU? ...
# 2  @msaid_didu @Mazing93 Gibran dapet giliran PER...
# 3  Y mau bagaimana lagi, Indonesia butuh seorang ...
# 4  204 Juta Data Pemilih Bocor Dibobol Hacker, KP...
#
#                                            cleansing
# 0  tvOneNews Inikah dampak data pemilih yg bocor ...
# 1  Bisa gak sih ada Mosi Tidak Percaya sama KPU S...
# 2  msaiddidu Mazing Gibran dapet giliran PERTAMA ...
# 3  Y mau bagaimana lagi Indonesia butuh seorang y...
# 4   Juta Data Pemilih Bocor Dibobol Hacker KPU Bu...

# %%
print(df['cleansing'][1])
# Out:
# Bisa gak sih ada Mosi Tidak Percaya sama KPU Soalnya org nya piliham Mukidi semua ingat data pemilih bocor di server KPU trus ada yg jual 🤦‍♂️

# %%
#ubah menjadi huruf kecil semua (case folding dan tokenization), membagi teks atau kalimat menjadi unit-unit lebih kecil yang
df['Tokenization and Case Folding'] = df['cleansing'].apply(lambda x: x.lower().split())
df.head()
# Out:
#                                            full_text  \
# 0  @tvOneNews Inikah dampak data pemilih yg bocor...
# 1  Bisa gak sih ada Mosi Tidak Percaya sama KPU? ...
# 2  @msaid_didu @Mazing93 Gibran dapet giliran PER...
# 3  Y mau bagaimana lagi, Indonesia butuh seorang ...
# 4  204 Juta Data Pemilih Bocor Dibobol Hacker, KP...
#
#                                            cleansing  \
# 0  tvOneNews Inikah dampak data pemilih yg bocor ...
# 1  Bisa gak sih ada Mosi Tidak Percaya sama KPU S...
# 2  msaiddidu Mazing Gibran dapet giliran PERTAMA ...
# 3  Y mau bagaimana lagi Indonesia butuh seorang y...
# 4   Juta Data Pemilih Bocor Dibobol Hacker KPU Bu...
#
#                        Tokenization and Case Folding
# 0  [tvonenews, inikah, dampak, data, pemilih, yg,...
# 1  [bisa, gak, sih, ada, mosi, tidak, percaya, sa...
# 2  [msaiddidu, mazing, gibran, dapet, giliran, pe...
# 3  [y, mau, bagaimana, lagi, indonesia, butuh, se...
# 4  [juta, data, pemilih, bocor, dibobol, hacker, ...

# %%
print(df['Tokenization and Case Folding'][1])
# Out:
# ['bisa', 'gak', 'sih', 'ada', 'mosi', 'tidak', 'percaya', 'sama', 'kpu', 'soalnya', 'org', 'nya', 'piliham', 'mukidi', 'semua', 'ingat', 'data', 'pemilih', 'bocor', 'di', 'server', 'kpu', 'trus', 'ada', 'yg', 'jual', '🤦\u200d♂️']

# %%
#filtering / stopword removal,Stopwords adalah kata-kata umum yang sering muncul dalam sebuah teks tetapi kurang memiliki nilai informatif dalam analisis teks.
from nltk.corpus import stopwords
nltk.download('stopwords')
stop_words = stopwords.words('indonesian')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
def remove_stopwords(text):
  return [word for word in text if word not in stop_words]

df['Filtering/stopword removal'] = df['Tokenization and Case Folding'].apply(lambda x: remove_stopwords(x))
df.head()
# Out:
#                                            full_text  \
# 0  @tvOneNews Inikah dampak data pemilih yg bocor...
# 1  Bisa gak sih ada Mosi Tidak Percaya sama KPU? ...
# 2  @msaid_didu @Mazing93 Gibran dapet giliran PER...
# 3  Y mau bagaimana lagi, Indonesia butuh seorang ...
# 4  204 Juta Data Pemilih Bocor Dibobol Hacker, KP...
#
#                                            cleansing  \
# 0  tvOneNews Inikah dampak data pemilih yg bocor ...
# 1  Bisa gak sih ada Mosi Tidak Percaya sama KPU S...
# 2  msaiddidu Mazing Gibran dapet giliran PERTAMA ...
# 3  Y mau bagaimana lagi Indonesia butuh seorang y...
# 4   Juta Data Pemilih Bocor Dibobol Hacker KPU Bu...
#
#                        Tokenization and Case Folding  \
# 0  [tvonenews, inikah, dampak, data, pemilih, yg,...
# 1  [bisa, gak, sih, ada, mosi, tidak, percaya, sa...
# 2  [msaiddidu, mazing, gibran, dapet, giliran, pe...
# 3  [y, mau, bagaimana, lagi, indonesia, butuh, se...
# 4  [juta, data, pemilih, bocor, dibobol, hacker, ...
#
#                           Filtering/stopword removal
# 0  [tvonenews, dampak, data, pemilih, yg, bocor, ...
# 1  [gak, sih, mosi, percaya, kpu, org, nya, pilih...
# 2  [msaiddidu, mazing, gibran, dapet, giliran, vi...
# 3  [y, indonesia, butuh, yg, sok, sok, mengerti, ...
# 4  [juta, data, pemilih, bocor, dibobol, hacker, ...

# %%
print(df['Filtering/stopword removal'][1])
# Out:
# ['gak', 'sih', 'mosi', 'percaya', 'kpu', 'org', 'nya', 'piliham', 'mukidi', 'data', 'pemilih', 'bocor', 'server', 'kpu', 'trus', 'yg', 'jual', '🤦\u200d♂️']

# %%
#steamming data

# !pip install Sastrawi

from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
from nltk.stem import PorterStemmer
from nltk.stem.snowball import SnowballStemmer
# Out:
# Collecting Sastrawi
#   Downloading Sastrawi-1.0.1-py2.py3-none-any.whl (209 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.7/209.7 kB 3.6 MB/s eta 0:00:00
# Installing collected packages: Sastrawi
# Successfully installed Sastrawi-1.0.1

# %%
factory = StemmerFactory()
stemmer = factory.create_stemmer()

def stem_text(text):
    return [stemmer.stem(word) for word in text]

df['stemming_data'] = df['Filtering/stopword removal'].apply(lambda x: ' '.join(stem_text(x)))
df.head()
# Out:
#                                            full_text  \
# 0  @tvOneNews Inikah dampak data pemilih yg bocor...
# 1  Bisa gak sih ada Mosi Tidak Percaya sama KPU? ...
# 2  @msaid_didu @Mazing93 Gibran dapet giliran PER...
# 3  Y mau bagaimana lagi, Indonesia butuh seorang ...
# 4  204 Juta Data Pemilih Bocor Dibobol Hacker, KP...
#
#                                            cleansing  \
# 0  tvOneNews Inikah dampak data pemilih yg bocor ...
# 1  Bisa gak sih ada Mosi Tidak Percaya sama KPU S...
# 2  msaiddidu Mazing Gibran dapet giliran PERTAMA ...
# 3  Y mau bagaimana lagi Indonesia butuh seorang y...
# 4   Juta Data Pemilih Bocor Dibobol Hacker KPU Bu...
#
#                        Tokenization and Case Folding  \
# 0  [tvonenews, inikah, dampak, data, pemilih, yg,...
# 1  [bisa, gak, sih, ada, mosi, tidak, percaya, sa...
# 2  [msaiddidu, mazing, gibran, dapet, giliran, pe...
# 3  [y, mau, bagaimana, lagi, indonesia, butuh, se...
# 4  [juta, data, pemilih, bocor, dibobol, hacker, ...
#
#                           Filtering/stopword removal  \
# 0  [tvonenews, dampak, data, pemilih, yg, bocor, ...
# 1  [gak, sih, mosi, percaya, kpu, org, nya, pilih...
# 2  [msaiddidu, mazing, gibran, dapet, giliran, vi...
# 3  [y, indonesia, butuh, yg, sok, sok, mengerti, ...
# 4  [juta, data, pemilih, bocor, dibobol, hacker, ...
#
#                                        stemming_data
# 0  tvonenews dampak data pilih yg bocor tsb kpu j...
# 1  gak sih mosi percaya kpu org nya piliham mukid...
# 2  msaiddidu mazing gibran dapet gilir visi misi ...
# 3  y indonesia butuh yg sok sok erti nyata nya ko...
# 4  juta data pilih bocor bobol hacker kpu buka suara

# %%
#drop data duplicate
df.drop_duplicates(subset="stemming_data", keep='first', inplace=True)
df.head()
# Out:
#                                            full_text  \
# 0  @tvOneNews Inikah dampak data pemilih yg bocor...
# 1  Bisa gak sih ada Mosi Tidak Percaya sama KPU? ...
# 2  @msaid_didu @Mazing93 Gibran dapet giliran PER...
# 3  Y mau bagaimana lagi, Indonesia butuh seorang ...
# 4  204 Juta Data Pemilih Bocor Dibobol Hacker, KP...
#
#                                            cleansing  \
# 0  tvOneNews Inikah dampak data pemilih yg bocor ...
# 1  Bisa gak sih ada Mosi Tidak Percaya sama KPU S...
# 2  msaiddidu Mazing Gibran dapet giliran PERTAMA ...
# 3  Y mau bagaimana lagi Indonesia butuh seorang y...
# 4   Juta Data Pemilih Bocor Dibobol Hacker KPU Bu...
#
#                        Tokenization and Case Folding  \
# 0  [tvonenews, inikah, dampak, data, pemilih, yg,...
# 1  [bisa, gak, sih, ada, mosi, tidak, percaya, sa...
# 2  [msaiddidu, mazing, gibran, dapet, giliran, pe...
# 3  [y, mau, bagaimana, lagi, indonesia, butuh, se...
# 4  [juta, data, pemilih, bocor, dibobol, hacker, ...
#
#                           Filtering/stopword removal  \
# 0  [tvonenews, dampak, data, pemilih, yg, bocor, ...
# 1  [gak, sih, mosi, percaya, kpu, org, nya, pilih...
# 2  [msaiddidu, mazing, gibran, dapet, giliran, vi...
# 3  [y, indonesia, butuh, yg, sok, sok, mengerti, ...
# 4  [juta, data, pemilih, bocor, dibobol, hacker, ...
#
#                                        stemming_data
# 0  tvonenews dampak data pilih yg bocor tsb kpu j...
# 1  gak sih mosi percaya kpu org nya piliham mukid...
# 2  msaiddidu mazing gibran dapet gilir visi misi ...
# 3  y indonesia butuh yg sok sok erti nyata nya ko...
# 4  juta data pilih bocor bobol hacker kpu buka suara

# %%
#save dataset hasil pre-processing data
df.to_csv('hasil_preprocessing_data_kpu.csv',encoding='utf8', index=False)

# %%
#vis data baru
data = pd.read_csv("hasil_preprocessing_data_kpu.csv")
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 183 entries, 0 to 182
# Data columns (total 5 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   full_text                      183 non-null    object
#  1   cleansing                      183 non-null    object
#  2   Tokenization and Case Folding  183 non-null    object
#  3   Filtering/stopword removal     183 non-null    object
#  4   stemming_data                  183 non-null    object
# dtypes: object(5)
# memory usage: 7.3+ KB

# %%
#vis original data wordcloud & frekuensi data
import pandas as pd
import numpy as np
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import matplotlib.pyplot as plt
df = ' '.join(data['stemming_data'].tolist())

stopwords = set(STOPWORDS)
stopwords.update(['https', 'co', 'RT', '...', 'amp'])
wc = WordCloud(stopwords=stopwords, background_color="black", max_words=100, height=400, width= 800)
wc.generate(df)

plt.figure(figsize=(10, 5))
plt.imshow(wc, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
#kata yang sering muncul
import matplotlib.pyplot as plt
from collections import Counter

text=" ".join(data["stemming_data"])

tokens = text.split()
word_counts = Counter(tokens)

top_words = word_counts.most_common(10)
word, count = zip(*top_words)

colors = plt.cm.Paired(range(len(word)))

plt.figure(figsize=(10, 6))
bars = plt.bar(word, count, color=colors)
plt.xlabel("Kata")
plt.ylabel("Frekuensi")
plt.title("Kata-kata yang sering muncul")
plt.xticks(rotation=45)

for bar, num in zip(bars, count):
  plt.text(bar.get_x() + bar.get_width() / 2 - 0.1, num+ 1, str(num), fontsize=12, color='black', ha='center')

plt.show()
